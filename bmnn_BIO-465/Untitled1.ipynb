# %%
# %matplotlib inline
import brian2 as b2
import matplotlib.pyplot as plt
import numpy as np
from neurodynex.leaky_integrate_and_fire import LIF
from neurodynex.tools import input_factory, plot_tools
import seaborn as sns
sns.set()
sns.set_style('dark')

# %%
LIF.getting_started()
LIF.print_default_parameters()
# Out:
# nr of spikes: 0
# nr of spikes: 5
# Resting potential: -0.07
# Reset voltage: -0.065
# Firing threshold: -0.05
# Membrane resistance: 10000000.0
# Membrane time-scale: 0.008
# Absolute refractory period: 0.002

# %%
LIF.simulate_LIF_neuron(input_current,
                        simulation_time=5. * msecond,
                        v_rest=-70. * mvolt,
                        v_reset=-65. * mvolt,
                        firing_threshold=-50. * mvolt,
                        membrane_resistance=10. * Mohm,
                        membrane_time_scale=8. * msecond,
                        abs_refractory_period=2. * msecond)
# Out:
# ---------------------------------------------------------------------------
# DimensionMismatchError                    Traceback (most recent call last)
# <ipython-input-24-b72316f572d3> in <module>()
#      11                         membrane_resistance=10. * Mohm,
#      12                         membrane_time_scale=8. * msecond,
# ---> 13                         abs_refractory_period=2. * msecond)
#      14
#
# /home/sigis/anaconda3/envs/bmnn/lib/python2.7/site-packages/neurodynex/leaky_integrate_and_fire/LIF.pyc in simulate_LIF_neuron(input_current, simulation_time, v_rest, v_reset, firing_threshold, membrane_resistance, membrane_time_scale, abs_refractory_period)
#      89         1, model=eqs, reset="v=v_reset", threshold="v>firing_threshold",
#      90         refractory=abs_refractory_period, method="linear")
# ---> 91     neuron.v = v_rest  # set initial value
#      92
#      93     # monitoring membrane potential of neuron and injecting current
#
# /home/sigis/anaconda3/envs/bmnn/lib/python2.7/site-packages/brian2/groups/neurongroup.pyc in __setattr__(self, key, value)
#     723                                  'model equations.') % key)
#     724             else:
# --> 725                 Group.__setattr__(self, key, value, level=1)
#     726
#     727     def __getitem__(self, item):
#
# /home/sigis/anaconda3/envs/bmnn/lib/python2.7/site-packages/brian2/groups/group.pyc in __setattr__(self, name, val, level)
#     417                                                  'value with units %r, but got '
#     418                                                  '{value}') % (name, get_unit(var.dim)),
# --> 419                                                 value=val)
#     420             if var.read_only:
#     421                 raise TypeError('Variable %s is read-only.' % name)
#
# /home/sigis/anaconda3/envs/bmnn/lib/python2.7/site-packages/brian2/units/fundamentalunits.pyc in fail_for_dimension_mismatch(obj1, obj2, error_message, **error_quantities)
#     182         # restate this unit (it is probably mentioned in the text already)
#     183         if obj2 is None or isinstance(obj2, (Dimension, Unit)):
# --> 184             raise DimensionMismatchError(error_message, dim1)
#     185         else:
#     186             raise DimensionMismatchError(error_message, dim1, dim2)
#
# DimensionMismatchError: v should be set with a value with units volt, but got -14.0 (unit is 1).
